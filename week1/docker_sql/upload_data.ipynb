# %%
import pandas as pd
from sqlalchemy import create_engine
import time

# %%
pd.__version__
# Out:
# '1.3.4'

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv', nrows=100)

# %%
df.shape
# Out:
# (100, 18)

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# 1           0.20           1                  N           238           151
# 2          14.70           1                  N           132           165
# 3          10.60           1                  N           138           132
# 4           4.94           1                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
#Load entire csv to postgres table using chunks

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')

# %%
#load first chunk
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='replace', index=False)
# Out:
# CPU times: user 3.56 s, sys: 35.3 ms, total: 3.59 s
# Wall time: 6.64 s

# %%
pd.read_sql("select * from yellow_taxi_data limit 10", con=engine)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# 5         1  2021-01-01 00:16:29   2021-01-01 00:24:30                1
# 6         1  2021-01-01 00:00:28   2021-01-01 00:17:28                1
# 7         1  2021-01-01 00:12:29   2021-01-01 00:30:34                1
# 8         1  2021-01-01 00:39:16   2021-01-01 01:00:13                1
# 9         1  2021-01-01 00:26:12   2021-01-01 00:39:46                2
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# ...

# %%
#Load remaining chunks

while True:
    
    t_start = time.time()
    
    df = next(df_iter)

    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    
    df.to_sql(name='yellow_taxi_data', con=engine, index=False, if_exists='append')
    
    time.sleep(1)
    
    del df
    
    time.sleep(1)
    
    t_end = time.time()

    print('Inserted another chunk, took %.3f second' % (t_end - t_start))
# Out:
# Inserted another chunk, took 8.027 second
# Inserted another chunk, took 8.672 second
# Inserted another chunk, took 8.010 second
# Inserted another chunk, took 8.588 second
# Inserted another chunk, took 8.017 second
# Inserted another chunk, took 8.675 second
# Inserted another chunk, took 8.524 second
# Inserted another chunk, took 9.172 second
# Inserted another chunk, took 8.219 second
# Inserted another chunk, took 8.877 second
# Inserted another chunk, took 8.143 second
# /home/kelvin/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3364: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Inserted another chunk, took 8.638 second
# Inserted another chunk, took 5.865 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ...

# %%
pd.read_sql("select count(1) from yellow_taxi_data", con=engine)
# Out:
#      count
# 0  1369765

# %%
#pd.read_sql("drop table yellow_taxi_data", con=engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# /tmp/ipykernel_69351/998505751.py in <module>
# ----> 1 pd.read_sql("drop table yellow_taxi_data", con=engine)
#
# ~/.local/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     626         )
#     627     else:
# --> 628         return pandas_sql.read_query(
#     629             sql,
#     630             index_col=index_col,
#
# ~/.local/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1591             )
#    1592         else:
# -> 1593             data = result.fetchall()
#    1594             frame = _wrap_result(
#    1595                 data,
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/result.py in fetchall(self)
# ...

# %% [raw]
# query = """
# SELECT *
# FROM pg_catalog.pg_tables
# WHERE schemaname != 'pg_catalog' AND
#     schemaname != 'information_schema';
# """
#
# pd.read_sql(query, con=engine)
